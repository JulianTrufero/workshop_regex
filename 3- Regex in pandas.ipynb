# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-libraries" data-toc-modified-id="Import-libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import libraries</a></span></li><li><span><a href="#Regex-&amp;-Pandas" data-toc-modified-id="Regex-&amp;-Pandas-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Regex &amp; Pandas</a></span><ul class="toc-item"><li><span><a href="#Apply-&amp;-lambda" data-toc-modified-id="Apply-&amp;-lambda-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Apply &amp; lambda</a></span></li><li><span><a href="#Let's-get-to-work!" data-toc-modified-id="Let's-get-to-work!-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Let's get to work!</a></span><ul class="toc-item"><li><span><a href="#Sender-info" data-toc-modified-id="Sender-info-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Sender info</a></span></li><li><span><a href="#Sender-name" data-toc-modified-id="Sender-name-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Sender name</a></span></li><li><span><a href="#Dates" data-toc-modified-id="Dates-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Dates</a></span></li><li><span><a href="#Time-sent" data-toc-modified-id="Time-sent-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Time sent</a></span></li><li><span><a href="#Subject" data-toc-modified-id="Subject-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>Subject</a></span></li></ul></li><li><span><a href="#Replace-in-pandas" data-toc-modified-id="Replace-in-pandas-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Replace in pandas</a></span></li></ul></li></ul></div>

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import re

# to import functions from src folder
import sys
sys.path.append('../')

import src.cleaning_functions as fc

# %% [markdown]
# ### Regex & Pandas

# %% [markdown]
# #### Apply & lambda

# %%
resultado_scrapping = ["mi DNI es 00000000A", "hola qué tal es 40.00.11.00X", "1234567E", "78-78-78-78P"]

# %%
df = pd.DataFrame(resultado_scrapping, columns = ["info"])
df.head()
# Out:
#                            info
# 0           mi DNI es 00000000A
# 1  hola qué tal es 40.00.11.00X
# 2                      1234567E
# 3                  78-78-78-78P

# %%
pattern = "\d+[\.-]*\w{1}"
df['DNI'] = df["info"].apply(lambda x: re.findall(pattern, x))
df
# Out:
#                            info                   DNI
# 0           mi DNI es 00000000A           [00000000A]
# 1  hola qué tal es 40.00.11.00X  [40.0, 0.1, 1.0, 0X]
# 2                      1234567E            [1234567E]
# 3                  78-78-78-78P  [78-7, 8-7, 8-7, 8P]

# %% [markdown]
# #### Let's get to work!
#
# In this example we are going to take an email and extract:
#
# - The person sending the email
#
#
# - The person the email is sent to
#
#
# - The date the email was sent
#
#
# - The time the email was sent
#
#
# - Subject of the email

# %%
# the first thing we are going to do is read the txt file 
email = open("data/emails.txt", "r").read()

# %%
# Remember the split? Let's remove the first part of the mail  
content = re.split("From r", email)
len(content)
# Out:
# 3978

# %%
print(content[2])
# Out:
#   Thu Oct 31 08:11:39 2002
# Return-Path: <bensul2004nng@spinfinder.com>
# X-Sieve: cmu-sieve 2.0
# Return-Path: <bensul2004nng@spinfinder.com>
# Message-Id: <200210311310.g9VDANt24674@bloodwork.mr.itd.UM>
# From: "Mr. Ben Suleman" <bensul2004nng@spinfinder.com>
# Date: Thu, 31 Oct 2002 05:10:00
# To: R@M
# Subject: URGENT ASSISTANCE /RELATIONSHIP (P)
# MIME-Version: 1.0
# Content-Type: text/plain;charset="iso-8859-1"
# Content-Transfer-Encoding: 7bit
# Status: O
#
# Dear Friend,
#
# I am Mr. Ben Suleman a custom officer and work as Assistant controller of the Customs and Excise department Of the Federal Ministry of Internal Affairs stationed at the Murtala Mohammed International Airport, Ikeja, Lagos-Nigeria.
#
# ...

# %%
print(len(content[2]))
# Out:
# 3692

# %%
content[2][:10]
# Out:
# '  Thu Oct '

# %%
# we create an empty dictionary where we will store each of the parts of the email   
email_info = {}

# %% [markdown]
# ##### Sender info

# %%
# we will search for all elements starting with "From :".
info_sender = re.findall('From:.*',email)
info_sender[:4]
# Out:
# ['From: "MR. JAMES NGOLA." <james_ngola2002@maktoob.com>',
#  'From: "Mr. Ben Suleman" <bensul2004nng@spinfinder.com>',
#  'From: "PRINCE OBONG ELEME" <obong_715@epatra.com>',
#  'From: "PRINCE OBONG ELEME" <obong_715@epatra.com>']

# %%
type(info_sender)
# Out:
# list

# %%
pattern_send = r"[\w]+@[\w\.]*"

# %%
email_info['sender_email'] = fc.get_info(pattern_send, info_sender,email_info, "sender_email")

# %%
email_info
# Out:
# {'sender_email': ['james_ngola2002@maktoob.com',
#   'bensul2004nng@spinfinder.com',
#   'obong_715@epatra.com',
#   'obong_715@epatra.com',
#   'm_abacha03@www.com',
#   'davidkuta@postmark.net',
#   'tunde_dosumu@lycos.com',
#   'william2244drallo@maktoob.com',
#   'abdul_817@rediffmail.com',
#   'barrister_td@lycos.com',
#   'temijohnson2@rediffmail.com',
#   'sjordan@diplomats.com',
#   'p_brown2@lawyer.com',
#   'No info',
#   'mic_k1@post.com',
#   'mikebunduu1@rediffmail.com',
#   'elixwilliam@usa.com',
#   'anayoawka@hotmail.com',
#   'anayoawka@hotmail.com',
#   'victorloma@netscape.net',
#   'victorloma@netscape.net',
#   'james_ngola2002@maktoob.com',
#   'martinchime@usa.com',
#   'mboro1555@post.com',
#   'martinchime@borad.com',
#   'martinchime@borad.com',
#   'edema_mb@phantomemail.com',
#   'edema_mb@phantomemail.com',
#   'adewilliams_ade@lawyer.com',
#   'smithkam2@post.com',
#   'sesm@omaninfo.com',
#   'obinaokoro@37.com',
#   'jamesalbert0@eircom.net',
# ...

# %%
email_info['sender_email'][:4]
# Out:
# ['james_ngola2002@maktoob.com',
#  'bensul2004nng@spinfinder.com',
#  'obong_715@epatra.com',
#  'obong_715@epatra.com']

# %% [markdown]
# #####  Sender name

# %%
pattern_sender = r":.*<"

# %%
email_info['sender_name'] = fc.get_sender(pattern_sender, info_sender,email_info, "sender_name")

# %%
email_info['sender_name'][:4]
# Out:
# ['"MR. JAMES NGOLA."',
#  '"Mr. Ben Suleman"',
#  '"PRINCE OBONG ELEME"',
#  '"PRINCE OBONG ELEME"']

# %% [markdown]
# ##### Dates

# %%
print(content[1])
# Out:
#   Wed Oct 30 21:41:56 2002
# Return-Path: <james_ngola2002@maktoob.com>
# X-Sieve: cmu-sieve 2.0
# Return-Path: <james_ngola2002@maktoob.com>
# Message-Id: <200210310241.g9V2fNm6028281@cs.CU>
# From: "MR. JAMES NGOLA." <james_ngola2002@maktoob.com>
# Reply-To: james_ngola2002@maktoob.com
# To: webmaster@aclweb.org
# Date: Thu, 31 Oct 2002 02:38:20 +0000
# Subject: URGENT BUSINESS ASSISTANCE AND PARTNERSHIP
# X-Mailer: Microsoft Outlook Express 5.00.2919.6900 DM
# MIME-Version: 1.0
# Content-Type: text/plain; charset="us-ascii"
# Content-Transfer-Encoding: 8bit
# X-MIME-Autoconverted: from quoted-printable to 8bit by sideshowmel.si.UM id g9V2foW24311
# Status: O
#
# FROM:MR. JAMES NGOLA.
# CONFIDENTIAL TEL: 233-27-587908.
# E-MAIL: (james_ngola2002@maktoob.com).
#
# URGENT BUSINESS ASSISTANCE AND PARTNERSHIP.
#
#
# DEAR FRIEND,
#
# ...

# %%
dates = re.findall(r"Date:.*",email)
dates[:4]
# Out:
# ['Date: Thu, 31 Oct 2002 02:38:20 +0000',
#  'Date: Thu, 31 Oct 2002 05:10:00',
#  'Date: Thu, 31 Oct 2002 22:17:55 +0100',
#  'Date: Thu, 31 Oct 2002 22:44:20']

# %%
pattern_date = r"\d+\s\w{3}\s\d+"

# %%
email_info['date_sent'] = fc.get_info(pattern_date, dates,email_info, "date_sent")

# %%
email_info['date_sent'][:4]
# Out:
# ['31 Oct 2002', '31 Oct 2002', '31 Oct 2002', '31 Oct 2002']

# %% [markdown]
# ##### Time sent

# %%
pattern_time = r"\d{2}:\d{2}:\d{2}"

# %%
email_info['time_sent'] = fc.get_info(pattern_time, dates,email_info, "time_sent")

# %%
email_info['time_sent'][:4]
# Out:
# ['02:38:20', '05:10:00', '22:17:55', '22:44:20']

# %% [markdown]
# ##### Subject

# %%
print(content[1])
# Out:
#   Wed Oct 30 21:41:56 2002
# Return-Path: <james_ngola2002@maktoob.com>
# X-Sieve: cmu-sieve 2.0
# Return-Path: <james_ngola2002@maktoob.com>
# Message-Id: <200210310241.g9V2fNm6028281@cs.CU>
# From: "MR. JAMES NGOLA." <james_ngola2002@maktoob.com>
# Reply-To: james_ngola2002@maktoob.com
# To: webmaster@aclweb.org
# Date: Thu, 31 Oct 2002 02:38:20 +0000
# Subject: URGENT BUSINESS ASSISTANCE AND PARTNERSHIP
# X-Mailer: Microsoft Outlook Express 5.00.2919.6900 DM
# MIME-Version: 1.0
# Content-Type: text/plain; charset="us-ascii"
# Content-Transfer-Encoding: 8bit
# X-MIME-Autoconverted: from quoted-printable to 8bit by sideshowmel.si.UM id g9V2foW24311
# Status: O
#
# FROM:MR. JAMES NGOLA.
# CONFIDENTIAL TEL: 233-27-587908.
# E-MAIL: (james_ngola2002@maktoob.com).
#
# URGENT BUSINESS ASSISTANCE AND PARTNERSHIP.
#
#
# DEAR FRIEND,
#
# ...

# %%
subjects=re.findall(r"Subject:.*",email)
subjects[:4]
# Out:
# ['Subject: URGENT BUSINESS ASSISTANCE AND PARTNERSHIP',
#  'Subject: URGENT ASSISTANCE /RELATIONSHIP (P)',
#  'Subject: GOOD DAY TO YOU',
#  'Subject: GOOD DAY TO YOU']

# %%
pattern_subject = r":.*"

# %%
email_info['subject'] = fc.get_subject(pattern_subject, subjects,email_info, "subject")

# %%
email_info['subject'][:4]
# Out:
# ['URGENT BUSINESS ASSISTANCE AND PARTNERSHIP',
#  'URGENT ASSISTANCE /RELATIONSHIP (P)',
#  'GOOD DAY TO YOU',
#  'GOOD DAY TO YOU']

# %% [markdown]
# Ok... we have all the information in a dicctionary 💪
#
# **The next step is create a pandas dataframe with this dicctionary**

# %%
df = pd.DataFrame.from_dict(email_info, orient='index')

# %%
df2 = df.T
df2.sample(10)
# Out:
#                         sender_email                       sender_name  \
# 808   dr_mrs_estrada@homenetmail.com                  "Dr Mrs Estrada"
# 284         gregoryprem@incamail.com                 "GREGORY PREMIER"
# 2103        tony_silver1@hotmail.com                     "TONY SILVER"
# 3372         davidclifford@myway.com                  "David Clifford"
# 2580                         No info                           No info
# 3176          ateeq_khan11@plasa.com                      "ateeq khan"
# 871             ndidi_uwoma@jumpy.it                           No info
# 827       princesshasihatu@myway.com  "PRINCESS HASIHATU SESSEY COLA."
# 71         tundebalogun@omaninfo.com                "MR.TUNDE BALOGUN"
# 2955        danasante777@hotmail.com                      "dan asante"
#
#         date_sent time_sent                                           subject
# 808    1 Jul 2004  18:42:37
# 284   08 Jul 2003  18:52:12                            With Utmost Sincerity.
# ...

# %% [markdown]
# #### Replace in pandas

# %% [markdown]
# How to replace a string in pandas?
#
# In pandas we have the `str.replace` method that allows us to repalce each ocurrence of pattern/regex in the Series
# - Replace character/s under a single DataFrame column:
#
#
# ```python
# df['column name'] = df['column name'].str.replace('old character','new character', regex = True)
# ```
# - Replace character/s under the entire DataFrame:
#
# ```python
# df = df.replace('old character','new character', regex=True)
# ```
#
#
#
# More info [here](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.replace.html)

# %%
# create 
colors = {'first_set':  ['aa_bb_1','cc_dd_33333','ee_ff','gg_hh'],
          'second_set': ['ii_jj_','kk_ll_63','mm_nn','oo_pp_84']
         }

# %%
df = pd.DataFrame(colors, columns= ['first_set','second_set'])
df.head()
# Out:
#      first_set second_set
# 0      aa_bb_1     ii_jj_
# 1  cc_dd_33333   kk_ll_63
# 2        ee_ff      mm_nn
# 3        gg_hh   oo_pp_84

# %%
# Replace a Specific Character under a Single DataFrame Column
df['first_set'] = df['first_set'].str.replace('_','|')

# %%
df.head()
# Out:
#      first_set second_set
# 0      aa|bb|1     ii_jj_
# 1  cc|dd|33333   kk_ll_63
# 2        ee|ff      mm_nn
# 3        gg|hh   oo_pp_84

# %%
# Replace a Specific Character under the Entire DataFrame
df = df.replace(r'\_\d+','', regex=True)

# %%
df.head()
# Out:
#      first_set second_set
# 0      aa|bb|1     ii_jj_
# 1  cc|dd|33333      kk_ll
# 2        ee|ff      mm_nn
# 3        gg|hh      oo_pp
